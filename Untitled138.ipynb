# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/project_smartphone_data (1).csv')

# %%
df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#   brand_name  price  has_5g  has_nfc  has_ir_blaster processor_brand  \
# 0    oneplus  54999    True     True           False      snapdragon
# 1    oneplus  19989    True    False           False      snapdragon
# 2    samsung  16499    True    False           False          exynos
# 3   motorola  14999    True    False           False      snapdragon
# 4     realme  24999    True    False           False       dimensity
#
#    num_cores  processor_speed  battery_capacity  fast_charging_available  \
# 0        8.0              3.2            5000.0                        1
# 1        8.0              2.2            5000.0                        1
# 2        8.0              2.4            5000.0                        1
# 3        8.0              2.2            5000.0                        1
# 4        8.0              2.6            5000.0                        1
#
#    ram_capacity  internal_memory  refresh_rate       os  primary_camera_rear  \
# ...

# %%
df['brand_name'].value_counts().index
# Out:
# Index(['xiaomi', 'samsung', 'vivo', 'realme', 'oppo', 'motorola', 'apple',
#        'oneplus', 'poco', 'tecno', 'iqoo', 'infinix', 'huawei', 'google',
#        'honor', 'nokia', 'sony', 'itel', 'asus', 'nubia', 'nothing', 'lava',
#        'jio', 'ikall', 'letv', 'lg', 'micromax', 'redmi', 'gionee', 'doogee',
#        'oukitel', 'lyf', 'zte', 'lenovo', 'royole', 'leitz', 'sharp', 'cat',
#        'tcl', 'tesla', 'blu', 'cola', 'duoqin', 'leeco', 'blackview'],
#       dtype='object')

# %%
l = ['xiaomi', 'samsung', 'vivo', 'realme', 'oppo', 'motorola', 'apple',
       'oneplus', 'poco', 'tecno', 'iqoo', 'infinix', 'huawei', 'google',
       'honor', 'nokia', 'sony', 'itel', 'asus', 'nubia', 'nothing', 'lava',
       'jio']

# %%
df['brand_name'].value_counts()
# Out:
# xiaomi       132
# samsung      132
# vivo         111
# realme        97
# oppo          87
# motorola      52
# apple         46
# oneplus       42
# poco          41
# tecno         33
# iqoo          32
# infinix       29
# huawei        15
# google        14
# honor         13
# nokia         13
# sony           9
# itel           9
# asus           7
# nubia          6
# nothing        5
# lava           4
# jio            4
# ikall          3
# letv           3
# lg             3
# micromax       3
# redmi          3
# gionee         3
# doogee         2
# oukitel        2
# lyf            2
# zte            2
# lenovo         2
# royole         2
# leitz          1
# sharp          1
# cat            1
# tcl            1
# tesla          1
# blu            1
# cola           1
# duoqin         1
# leeco          1
# blackview      1
# Name: brand_name, dtype: int64

# %%
df = df.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-4a504d1ccf50> in <cell line: 1>()
# ----> 1 df = df.drop(columns=['Unnamed: 0'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
def lol(data):
  if data in l:
    return data
  else:
    return "others"

# %%
df['brand_name'] = df['brand_name'].apply(lol)

# %%
df['brand_name'].value_counts()
# Out:
# xiaomi      132
# samsung     132
# vivo        111
# realme       97
# oppo         87
# motorola     52
# apple        46
# oneplus      42
# poco         41
# others       40
# tecno        33
# iqoo         32
# infinix      29
# huawei       15
# google       14
# nokia        13
# honor        13
# itel          9
# sony          9
# asus          7
# nubia         6
# nothing       5
# jio           4
# lava          4
# Name: brand_name, dtype: int64

# %%
df.head()
# Out:
#   brand_name  price  has_5g  has_nfc  has_ir_blaster processor_brand  \
# 0    oneplus  54999    True     True           False      snapdragon
# 1    oneplus  19989    True    False           False      snapdragon
# 2    samsung  16499    True    False           False          exynos
# 3   motorola  14999    True    False           False      snapdragon
# 4     realme  24999    True    False           False       dimensity
#
#    num_cores  processor_speed  battery_capacity  fast_charging_available  \
# 0        8.0              3.2            5000.0                        1
# 1        8.0              2.2            5000.0                        1
# 2        8.0              2.4            5000.0                        1
# 3        8.0              2.2            5000.0                        1
# 4        8.0              2.6            5000.0                        1
#
#    ram_capacity  internal_memory  refresh_rate       os  primary_camera_rear  \
# ...

# %%
df['processor_brand'].value_counts().index
# Out:
# Index(['snapdragon', 'helio', 'dimensity', 'exynos', 'bionic', 'unisoc',
#        'tiger', 'google', 'kirin', 'spreadtrum', 'sc9863a', 'fusion',
#        'mediatek'],
#       dtype='object')

# %%
df['processor_brand'].value_counts().index

m = ['snapdragon', 'helio', 'dimensity', 'exynos', 'bionic', 'unisoc',
       'tiger']

# %%
def lol(data):
  if data in m:
    return data
  else:
    return "others"

# %%
df['processor_brand'] = df['processor_brand'].apply(lol)

# %%
df['processor_brand'].value_counts()
# Out:
# snapdragon    409
# helio         200
# dimensity     177
# exynos         70
# bionic         45
# unisoc         26
# tiger          24
# others         22
# Name: processor_brand, dtype: int64

# %%
df.to_csv('mobile_final.csv')

# %%
df
# Out:
#     brand_name  price  has_5g  has_nfc  has_ir_blaster processor_brand  \
# 0      oneplus  54999    True     True           False      snapdragon
# 1      oneplus  19989    True    False           False      snapdragon
# 2      samsung  16499    True    False           False          exynos
# 3     motorola  14999    True    False           False      snapdragon
# 4       realme  24999    True    False           False       dimensity
# ..         ...    ...     ...      ...             ...             ...
# 968   motorola  34990    True    False           False      snapdragon
# 969      honor  14990    True    False           False      snapdragon
# 970       poco  28990    True     True            True       dimensity
# 971   motorola  19990    True     True           False      snapdragon
# 972    samsung  24990    True    False           False          exynos
#
#      num_cores  processor_speed  battery_capacity  fast_charging_available  \
# ...

# %%
def bhu(data):
  if data == True:
    return 1
  else:
    return 0

# %%
df['has_5g'] = df['has_5g'].apply(bhu)

# %%
df['has_nfc'] = df['has_nfc'].apply(bhu)

# %%
df['has_ir_blaster'] = df['has_ir_blaster'].apply(bhu)

# %%
df
# Out:
#     brand_name  price  has_5g  has_nfc  has_ir_blaster processor_brand  \
# 0      oneplus  54999       1        1               0      snapdragon
# 1      oneplus  19989       1        0               0      snapdragon
# 2      samsung  16499       1        0               0          exynos
# 3     motorola  14999       1        0               0      snapdragon
# 4       realme  24999       1        0               0       dimensity
# ..         ...    ...     ...      ...             ...             ...
# 968   motorola  34990       1        0               0      snapdragon
# 969      honor  14990       1        0               0      snapdragon
# 970       poco  28990       1        1               1       dimensity
# 971   motorola  19990       1        1               0      snapdragon
# 972    samsung  24990       1        0               0          exynos
#
#      num_cores  processor_speed  battery_capacity  fast_charging_available  \
# ...

# %%
y = np.log(df['price'])
x = df.drop(columns=['price'])

# %%
import seaborn as sns
sns.distplot(y)
# Out:
# <ipython-input-199-578d37c7dc05>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)
# <Axes: xlabel='price', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#     brand_name  has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 672    infinix   False    False           False           helio        8.0
# 376    samsung    True     True           False          exynos        8.0
# 962   motorola    True     True           False      snapdragon        8.0
# 142        jio   False    False           False          exynos        4.0
# 279      apple   False     True           False          bionic        6.0
# ..         ...     ...      ...             ...             ...        ...
# 534     lenovo    True     True           False      snapdragon        8.0
# 584     xiaomi    True    False            True       dimensity        8.0
# 493     realme   False    False           False           tiger        8.0
# 527       poco   False    False            True           helio        8.0
# 168       letv   False    False           False           tiger        4.0
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,4,12])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8473175148146327
# MAE 0.20241686553507734

# %%
X_train , [0,4,12]
# Out:
#     brand_name  has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 672    infinix       0        0               0           helio        8.0
# 376    samsung       1        1               0          exynos        8.0
# 962   motorola       1        1               0      snapdragon        8.0
# 142        jio       0        0               0          exynos        4.0
# 279      apple       0        1               0          bionic        6.0
# ..         ...     ...      ...             ...             ...        ...
# 534     others       1        1               0      snapdragon        8.0
# 584     xiaomi       1        0               1       dimensity        8.0
# 493     realme       0        0               0           tiger        8.0
# 527       poco       0        0               1           helio        8.0
# 168     others       0        0               0           tiger        4.0
#
# ...

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.853619513722049
# MAE 0.2117180070758122
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8471922810646828
# MAE 0.21333310865419491
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = Lasso(alpha=0.002)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8526642088123677
# MAE 0.21127340892652816
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=6)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.6695638999466451
# MAE 0.3039584189873406
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7755362293694931
# MAE 0.2585395072673019
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7293649802638907
# MAE 0.27495061121889636

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=150,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8521453291703063
# MAE 0.20128084428704304

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7965846655079559
# MAE 0.2592062989473339
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=553)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8797666293595798
# MAE 0.1709424802572947

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=35,max_depth=5,learning_rate=0.2)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8747344717219638
# MAE 0.18753796026841613

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-45323cdeabbb> in <cell line: 20>()
#      18 ])
#      19
# ---> 20 pipe.fit(X_train,y_train)
#      21
#      22 y_pred = pipe.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     403             if self._final_estimator != "passthrough":
#     404                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     406
#     407         return self
#
# ...

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,2,3,4,12])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8649566960993748
# MAE 0.18971137240614186

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,4,12])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8780304612668579
# MAE 0.1735032347255571

# %%
import pickle
pickle.dump(df,open('df_mobile1.pkl','wb'))
pickle.dump(pipe,open('pipe_moble1.pkl','wb'))

# %%
X_train.columns.shape
# Out:
# (16,)

# %%
df['primary_camera_rear'].unique()
# Out:
# array([ 50. ,  64. , 108. ,  12. , 200. ,  13. ,  48. ,   8. ,  50.3,
#         12.2,   5. ,  54. ,  16. ,   2. ,  20. ,  47.2,  40. ,  24. ])

# %%
df['num_cores'].value_counts()
# Out:
# 8.0    893
# 6.0     45
# 4.0     35
# Name: num_cores, dtype: int64

# %%
df['battery_capacity'].unique()
# Out:
# array([ 5000.,  3279.,  4980.,  4500.,  3240.,  4700.,  4830.,  4800.,
#         4323.,  3110.,  5200.,  6000.,  4325.,  4600.,  4200.,  3500.,
#         3095.,  4020.,  3200.,  4400.,  4310.,  4820.,  3700.,  5160.,
#         5080.,  3900.,  4410.,  5020.,  2800.,  4352.,  4520.,  4810.,
#         4000.,  2050.,  2150.,  4610.,  5100.,  7000.,  4300.,  5500.,
#         4050.,  4355.,  3060.,  5003.,  2438.,  4250.,  3300.,  4450.,
#         4614.,  4870.,  4030.,  4350.,  4100., 21000.,  4860.,  4230.,
#         1900.,  3020.,  4730.,  3520.,  4080.,  5050.,  5600.,  4470.,
#         3360.,  3000.,  2230.,  1821.,  4015.,  3285.,  4360.,  3315.,
#         2000.,  3600.,  3100., 22000.,  2400.,  2500.,  4532.,  5065.,
#         4620.,  4780.,  3730.,  3400.,  2730.,  5180.,  8000.])

# %%
X_train
# Out:
#     brand_name  has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# 672    infinix   False    False           False           helio        8.0
# 376    samsung    True     True           False          exynos        8.0
# 962   motorola    True     True           False      snapdragon        8.0
# 142        jio   False    False           False          exynos        4.0
# 279      apple   False     True           False          bionic        6.0
# ..         ...     ...      ...             ...             ...        ...
# 534     others    True     True           False      snapdragon        8.0
# 584     xiaomi    True    False            True       dimensity        8.0
# 493     realme   False    False           False           tiger        8.0
# 527       poco   False    False            True           helio        8.0
# 168     others   False    False           False           tiger        4.0
#
# ...
